# %% [markdown]
# ## Import libraries

# %%
import os

# %% [markdown]
# ## Import images to openBIS

# %%
os.system("python3 /home/jovyan/aiida-openbis/Notebooks/importer/nanonis_importer.py https://local.openbis.ch/openbis /home/jovyan/aiida-openbis/Notebooks/importer/data")
# Out:
# Connected to https://local.openbis.ch/openbis -> token: admin-240605120451414xEFDC53BDE53A6E4B9F6BB64E7BB171B9
# Found 220 Nanonis .SXM files in /home/jovyan/aiida-openbis/Notebooks/importer/data
# SXM file: img_0188.sxm
# Created imaging .SXM dataset: 20240605120453044-2935
# SXM file: img_0202.sxm
# Created imaging .SXM dataset: 20240605120454672-2936
# SXM file: img_0204.sxm
# Created imaging .SXM dataset: 20240605120456320-2937
# SXM file: img_0218.sxm
# Created imaging .SXM dataset: 20240605120457838-2938
# SXM file: img_0178.sxm
# Created imaging .SXM dataset: 20240605120459376-2939
# SXM file: img_0015.sxm
# Created imaging .SXM dataset: 20240605120500865-2940
# SXM file: img_0136.sxm
# Created imaging .SXM dataset: 20240605120501788-2941
# SXM file: img_0118.sxm
# Created imaging .SXM dataset: 20240605120504105-2942
# SXM file: img_0147.sxm
# Created imaging .SXM dataset: 20240605120505797-2943
# SXM file: img_0116.sxm
# Created imaging .SXM dataset: 20240605120507462-2944
# ...
