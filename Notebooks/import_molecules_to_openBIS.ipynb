# %% [markdown]
# ## Import libraries

# %%
import os
import re
import pandas as pd
import numpy as np
import rdkit
import tempfile
import datetime
from rdkit.Chem import rdMolDescriptors
from pybis import Openbis
from rdkit.Chem import AllChem
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Functions

# %%
def is_nan(value):
    return value != value

def get_substances(filename: str) -> pd.DataFrame: 
    df = pd.read_excel(filename, header = 7)
    return df

def get_full_filepath(folderpath: str) -> list[str]:
    return [f"{folderpath}/{file}" for file in os.listdir(folderpath) if file.endswith(".cdxml")]

def read_file(filepath: str) -> str:
    with open(filepath, "rb") as f:
        return f.read()

def log_in(bisurl='openbis', bisuser='admin', bispasswd='changeit'):
    """Function to login to openBIS."""
    if Openbis(bisurl, verify_certificates=False).is_token_valid():
        session = Openbis(bisurl, verify_certificates=False)
    else:
        Openbis(bisurl, verify_certificates=False).login(bisuser, bispasswd, save_token=True)
        session = Openbis(bisurl, verify_certificates=False)
    return session

def create_object_openbis(session, object_type, object_experiment, object_props, parents):
    
    if len(parents) > 0:
        openbis_object = session.new_sample(
            type = object_type,
            experiment = object_experiment,
            props = object_props,
            parents = parents
        )
    else:
        openbis_object = session.new_sample(
            type = object_type,
            experiment = object_experiment,
            props = object_props
        )
    
    openbis_object.save()
    
    return openbis_object

def create_dataset_openbis(session, dataset_type, object_id, dataset_filepath):
    raw_ds = session.new_dataset(type = dataset_type, object = object_id, file = dataset_filepath)
    raw_ds.save()
    
def create_molecule_image(chem_mol):
    img = rdkit.Chem.Draw.MolToImage(chem_mol)
    tmpdir = tempfile.mkdtemp()
    struc_filepath = tmpdir + "/" + 'struc.png'
    img.save(struc_filepath)
    
    return struc_filepath

def get_openbis_object_by_property(session, object_type, property_value):
    for object in session.get_samples(type = object_type):
        if object.props.all()['$name'] == property_value:
            return object
        
def get_molecule_identifiers(molecule_filepath):
    molecule_identifier = molecule_filepath.split("/")[-1].split(".")[0]
    molecule_number = int(molecule_identifier[:-1])
    return molecule_identifier, molecule_number

def process_receive_date(receive_date):
    if isinstance(receive_date, str):
        processed_receive_date = receive_date.replace(".","/")
        processed_receive_date_split = processed_receive_date.split("/")
        if len(processed_receive_date_split) == 3:
            day, month, year = processed_receive_date.split("/")
            day, month, year = int(day), int(month), int(year)
            # The excel document contains different ways of writing the date...
            if month <= 12:
                processed_receive_date = f"{month}/{day}/{year}"
            else:
                processed_receive_date = f"{day}/{month}/{year}"
        else:
            processed_receive_date = None
    else:
        processed_receive_date = receive_date.strftime('%m/%d/%Y')
    
    return processed_receive_date

# %% [markdown]
# ## Connect to openBIS

# %%
session = log_in(bisurl='openbis', bisuser='admin', bispasswd='123456789')

# %% [markdown]
# ## Get molecules from CDXML files

# %%
all_substances_info = get_substances("/home/jovyan/backup_aiida-openbis/Inventories/list of substances.xlsx")

molecules_filepaths = get_full_filepath("/home/jovyan/backup_aiida-openbis/Molecules_CDXML")

molecules_metadata = []

available_molecules_openbis = [f"{molecule.props.all()['empa_number']}{molecule.props.all()['batch']}" for molecule in session.get_samples(type = "MOLECULE")]

for substance_idx, molecule_info in all_substances_info.iterrows():
    molecule_cdxml_found = False
    
    for molecule_filepath in molecules_filepaths:
        molecule_identifier, molecule_number = get_molecule_identifiers(molecule_filepath) # Molecule EMPA ID and EMPA number
        
        if is_nan(molecule_info["SERIES NUMBER"]) == False:
            if int(molecule_info["SERIES NUMBER"][0:3]) == molecule_number:
                molecule_batch = molecule_info["SERIES NUMBER"][3]
                molecule_identifier = f"{molecule_number}{molecule_batch}"
                molecule_cdxml_found = True
                break
        else:
            continue # If the series number does not exist, move to the next molecule in the list
    
    if molecule_cdxml_found:
        cdxml_molecule = read_file(molecule_filepath)
        molecules = rdkit.Chem.MolsFromCDXML(cdxml_molecule)
        
        if len(molecules) == 1:
            mol = molecules[0] # Get first molecule
            mol_chemical_formula = rdMolDescriptors.CalcMolFormula(mol) # Sum Formula
            mol_smiles = rdkit.Chem.MolToSmiles(mol) # Canonical Smiles
            
            if molecule_identifier.upper() not in available_molecules_openbis: # pyBIS returns vocabulary terms in capital letters

                molecule_metadata_dict = {}
                
                if is_nan(molecule_info["NAMES, FORMULA"]) == False:
                    if molecule_info["NAMES, FORMULA"].replace(" ", "") not in ["?", ""]: # There are names with
                        molecule_metadata_dict["$name"] = molecule_info["NAMES, FORMULA"]
                else:
                    molecule_metadata_dict["$name"] = molecule_identifier

                if is_nan(molecule_info["DETAILS, COMMENTS"]) == False:
                    molecule_metadata_dict["comments"] = molecule_info["DETAILS, COMMENTS"]

                if is_nan(molecule_info["DATE"]) == False:
                        processed_date = process_receive_date(molecule_info["DATE"])
                        if processed_date is not None:
                            molecule_metadata_dict["receive_date"] = processed_date

                if is_nan(molecule_info["STORAGE"]) == False:
                    molecule_metadata_dict["other_storage_condition"] = True
                    molecule_metadata_dict["other_storage_condition_specification"] = molecule_info["STORAGE"]

                if is_nan(molecule_info["ORIGIN"]) == False:
                    if molecule_info["ORIGIN"]!="?" and molecule_info["ORIGIN"].strip()!="":
                        molecule_metadata_dict["supplier"] = {"$name": molecule_info["ORIGIN"]}

                if is_nan(molecule_info["SYNTHESIZED BY"]) == False:
                    if molecule_info["SYNTHESIZED BY"]!="?" and molecule_info["SYNTHESIZED BY"].strip()!="":
                        molecule_metadata_dict["chemist"] = {"$name": molecule_info["SYNTHESIZED BY"]}
                
                molecule_metadata_dict["empa_number"] = molecule_number
                molecule_metadata_dict["batch"] = molecule_batch
                molecule_metadata_dict["sum_formula"] = mol_chemical_formula
                molecule_metadata_dict["smiles"] = mol_smiles
                
                molecule_parents = []
                
                # Connect supplier with molecule if there is a supplier available
                if "supplier" in molecule_metadata_dict:
                    
                    available_suppliers_openbis = [supplier.props.all()['$name'] for supplier in session.get_samples(type = "SUPPLIER")]
                    
                    # Create Supplier object or get it from openBIS (in case it is already there)
                    if molecule_metadata_dict["supplier"]["$name"] not in available_suppliers_openbis:
                        supplier_object = create_object_openbis(
                            session, 
                            "SUPPLIER", 
                            "/INSTITUTIONS/SUPPLIERS/SUPPLIERS_COLLECTION", 
                            molecule_metadata_dict["supplier"],
                            parents = []
                        )
                    else:
                        supplier_object = get_openbis_object_by_property(session, 
                                                                        "SUPPLIER", 
                                                                        molecule_metadata_dict["supplier"]["$name"]
                        )
                    
                    # Remove supplier information from the molecule metadata because it should be a connection to a SUPPLIER object and not a parameter
                    molecule_metadata_dict.pop("supplier")
                    
                    # Append supplier parent
                    molecule_parents.append(supplier_object)
                
                # Connect chemist with molecule if there is a chemist available
                if "chemist" in molecule_metadata_dict:
                    
                    available_chemists_openbis = [supplier.props.all()['$name'] for supplier in session.get_samples(type = "CHEMIST")]
                    
                    # Create Chemist object or get it from openBIS (in case it is already there)
                    if molecule_metadata_dict["chemist"]["$name"] not in available_chemists_openbis:
                        chemist_object = create_object_openbis(
                            session, 
                            "CHEMIST", 
                            "/PEOPLE/PEOPLE/CHEMISTS_COLLECTION", 
                            molecule_metadata_dict["chemist"],
                            parents = []
                        )
                    else:
                        chemist_object = get_openbis_object_by_property(session, 
                                                                        "CHEMIST", 
                                                                        molecule_metadata_dict["chemist"]["$name"]
                        )
                    
                    # Remove chemist information from the molecule metadata because it should be a connection to a CHEMIST object and not a parameter
                    molecule_metadata_dict.pop("chemist")
                    
                    # Append supplier parent
                    molecule_parents.append(chemist_object)
                
                # Create molecule object
                molecule_object = create_object_openbis(
                    session, 
                    "MOLECULE", 
                    "/MATERIALS/MOLECULES/MOLECULES_EXP_1", 
                    molecule_metadata_dict,
                    parents = molecule_parents
                )
                
                # Generate molecule image
                chem_mol = rdkit.Chem.MolFromSmiles(mol_smiles)
                
                if chem_mol is not None:
                    AllChem.Compute2DCoords(chem_mol) # Add coords to the atoms in the molecule
                    struc_filepath = create_molecule_image(chem_mol)
                    
                    # Send molecule image to openBIS
                    create_dataset_openbis(
                        session, 
                        'ELN_PREVIEW',
                        molecule_object, 
                        struc_filepath
                    )
                    
                else:
                    print(f"Cannot generate molecule image for {molecule_identifier}")
                    
                # Send molecule cdxml to openBIS
                create_dataset_openbis(
                    session, 
                    'RAW_DATA', 
                    molecule_object, 
                    molecule_filepath
                )
                
            else:
                print(f"Molecule {molecule_identifier} already in openBIS.")
                
        elif len(molecules) > 1:
            print(f"There are more than one molecule in the file: {molecule_filepath}")  
        else:
            print(f"There are no molecules in the file: {molecule_filepath}")
    else:
        print(f"The CDXML of the molecule {molecule_info['SERIES NUMBER']} was not found!")
# Out:
# List of substances
# Molecule 679b already in openBIS.
# Molecule 679a already in openBIS.
# Molecule 678a already in openBIS.
# Molecule 677a already in openBIS.
# Molecule 676a already in openBIS.
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/675a.cdxml
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/674a.cdxml
# Molecule 673a already in openBIS.
# Molecule 672a already in openBIS.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/668a.cdxml
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# There are no molecules in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/664a.cdxml
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# There are no molecules in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/661a.cdxml
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# Molecule 654a already in openBIS.
# Molecule 653a already in openBIS.
# Molecule 652a already in openBIS.
# Molecule 651a already in openBIS.
# Molecule 650a already in openBIS.
# Molecule 649a already in openBIS.
# Molecule 648a already in openBIS.
# Molecule 647b already in openBIS.
# Molecule 647a already in openBIS.
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/646a.cdxml
# Molecule 645a already in openBIS.
# Molecule 644a already in openBIS.
# Molecule 643a already in openBIS.
# Molecule 642a already in openBIS.
# Molecule 641a already in openBIS.
# Molecule 640a already in openBIS.
# Molecule 639a already in openBIS.
# Molecule 638a already in openBIS.
# Molecule 637a already in openBIS.
# Molecule 636a already in openBIS.
# Molecule 635a already in openBIS.
# Molecule 634a already in openBIS.
# Molecule 633a already in openBIS.
# Molecule 632a already in openBIS.
# Molecule 631a already in openBIS.
# Molecule 630a already in openBIS.
# The CDXML of the molecule 281b was not found!
# Molecule 628a already in openBIS.
# Molecule 627c already in openBIS.
# Molecule 627b already in openBIS.
# Molecule 627a already in openBIS.
# Molecule 626a already in openBIS.
# Molecule 625a already in openBIS.
# Molecule 623b already in openBIS.
# Molecule 624b already in openBIS.
# Molecule 623a already in openBIS.
# Molecule 622a already in openBIS.
# Molecule 621b already in openBIS.
# Molecule 621a already in openBIS.
# Molecule 620a already in openBIS.
# Molecule 619a already in openBIS.
# Molecule 618b already in openBIS.
# Molecule 618a already in openBIS.
# Molecule 617a already in openBIS.
# Molecule 616a already in openBIS.
# Molecule 615a already in openBIS.
# Molecule 614a already in openBIS.
# Molecule 613a already in openBIS.
# Molecule 612a already in openBIS.
# There are no molecules in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/611a.cdxml
# The CDXML of the molecule 610a was not found!
# Molecule 609b already in openBIS.
# Molecule 609a already in openBIS.
# Molecule 608a already in openBIS.
# Molecule 607a already in openBIS.
# Molecule 606a already in openBIS.
# Molecule 605a already in openBIS.
# Molecule 604a already in openBIS.
# Molecule 603a already in openBIS.
# Molecule 602a already in openBIS.
# Molecule 601a already in openBIS.
# Molecule 600a already in openBIS.
# Molecule 599a already in openBIS.
# Molecule 598a already in openBIS.
# Molecule 597a already in openBIS.
# Molecule 596a already in openBIS.
# Molecule 595a already in openBIS.
# Molecule 594a already in openBIS.
# Molecule 593b already in openBIS.
# Molecule 593a already in openBIS.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# Molecule 592a already in openBIS.
# Molecule 591a already in openBIS.
# Molecule 590a already in openBIS.
# Molecule 589a already in openBIS.
# Molecule 588a already in openBIS.
# Molecule 587b already in openBIS.
# Molecule 587a already in openBIS.
# Molecule 586a already in openBIS.
# Molecule 585a already in openBIS.
# Molecule 584b already in openBIS.
# Molecule 584a already in openBIS.
# Molecule 583a already in openBIS.
# Molecule 582a already in openBIS.
# Molecule 581a already in openBIS.
# Molecule 580b already in openBIS.
# Molecule 580a already in openBIS.
# Molecule 579a already in openBIS.
# Molecule 578a already in openBIS.
# Molecule 577a already in openBIS.
# Molecule 576a already in openBIS.
# Molecule 575a already in openBIS.
# Molecule 574a already in openBIS.
# Molecule 573a already in openBIS.
# Molecule 572a already in openBIS.
# Molecule 571a already in openBIS.
# Molecule 570a already in openBIS.
# Molecule 569a already in openBIS.
# Molecule 568a already in openBIS.
# Molecule 567a already in openBIS.
# Molecule 566a already in openBIS.
# Molecule 565a already in openBIS.
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/564a.cdxml
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/564a.cdxml
# Molecule 563a already in openBIS.
# Molecule 562a already in openBIS.
# Molecule 561a already in openBIS.
# Molecule 560a already in openBIS.
# Molecule 559a already in openBIS.
# Molecule 558a already in openBIS.
# Molecule 557a already in openBIS.
# Molecule 556a already in openBIS.
# Molecule 555a already in openBIS.
# Molecule 554a already in openBIS.
# Molecule 553a already in openBIS.
# Molecule 552a already in openBIS.
# Molecule 551a already in openBIS.
# Molecule 550a already in openBIS.
# Molecule 549a already in openBIS.
# Molecule 548b already in openBIS.
# Molecule 548a already in openBIS.
# Molecule 547b already in openBIS.
# Molecule 547a already in openBIS.
# Molecule 546b already in openBIS.
# Molecule 546a already in openBIS.
# Molecule 545a already in openBIS.
# Molecule 544d already in openBIS.
# Molecule 544c already in openBIS.
# Molecule 544b already in openBIS.
# Molecule 544a already in openBIS.
# Molecule 543a already in openBIS.
# Molecule 542a already in openBIS.
# Molecule 541a already in openBIS.
# Molecule 540b already in openBIS.
# Molecule 540a already in openBIS.
# Molecule 539c already in openBIS.
# Molecule 539b already in openBIS.
# Molecule 539a already in openBIS.
# Molecule 538b already in openBIS.
# Molecule 538a already in openBIS.
# Molecule 537a already in openBIS.
# Molecule 536e already in openBIS.
# Molecule 536d already in openBIS.
# Molecule 536c already in openBIS.
# Molecule 536b already in openBIS.
# Molecule 536a already in openBIS.
# Molecule 535d already in openBIS.
# Molecule 535c already in openBIS.
# Molecule 535b already in openBIS.
# Molecule 535a already in openBIS.
# Molecule 534a already in openBIS.
# Molecule 533a already in openBIS.
# Molecule 532a already in openBIS.
# Molecule 531a already in openBIS.
# Molecule 530a already in openBIS.
# Molecule 529a already in openBIS.
# Molecule 528a already in openBIS.
# Molecule 527c already in openBIS.
# Molecule 527b already in openBIS.
# Molecule 527a already in openBIS.
# Molecule 526a already in openBIS.
# Molecule 525a already in openBIS.
# Molecule 524a already in openBIS.
# Molecule 523a already in openBIS.
# Molecule 522a already in openBIS.
# Molecule 521b already in openBIS.
# Molecule 521a already in openBIS.
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/520a.cdxml
# There are more than one molecule in the file: /home/jovyan/backup_aiida-openbis/Molecules_CDXML/520a.cdxml
# Molecule 519a already in openBIS.
# Molecule 518a already in openBIS.
# Molecule 517a already in openBIS.
# Molecule 516a already in openBIS.
# Molecule 515a already in openBIS.
# Molecule 514a already in openBIS.
# Molecule 513a already in openBIS.
# Molecule 512a already in openBIS.
# Molecule 511a already in openBIS.
# Molecule 510a already in openBIS.
# Molecule 509a already in openBIS.
# Molecule 508a already in openBIS.
# sample successfully created.
# DataSet successfully created.
# DataSet successfully created.
# Molecule 507d already in openBIS.
# Molecule 507c already in openBIS.
# Molecule 507b already in openBIS.
# Molecule 507a already in openBIS.
# Molecule 506a already in openBIS.
# Molecule 505a already in openBIS.
# Molecule 504a already in openBIS.
# Molecule 503a already in openBIS.
# Molecule 502a already in openBIS.
# Molecule 502a already in openBIS.
# Molecule 501a already in openBIS.
# Molecule 500a already in openBIS.
# Molecule 499a already in openBIS.
# Molecule 498a already in openBIS.
# Molecule 497a already in openBIS.
# Molecule 496a already in openBIS.
# Molecule 495a already in openBIS.
# Molecule 494a already in openBIS.
# Molecule 493a already in openBIS.
# Molecule 492a already in openBIS.
# Molecule 491a already in openBIS.
# Molecule 490a already in openBIS.
# Molecule 489a already in openBIS.
# Molecule 488a already in openBIS.
# Molecule 487a already in openBIS.
# Molecule 486a already in openBIS.
# Molecule 485a already in openBIS.
# Molecule 484a already in openBIS.
