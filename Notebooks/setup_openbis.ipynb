# %% [markdown]
# ## Import libraries

# %%
import os
import re
import json
import pandas as pd
import numpy as np
from pybis import Openbis
import warnings
import string
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Functions

# %%
def load_json(filepath: str) -> dict:
    return json.load(open(filepath, "r"))

def log_in(bisurl='openbis', bisuser='admin', bispasswd='changeit'):
    """Function to login to openBIS."""
    if Openbis(bisurl, verify_certificates=False).is_token_valid():
        session = Openbis(bisurl, verify_certificates=False)
    else:
        Openbis(bisurl, verify_certificates=False).login(bisuser, bispasswd, save_token=True)
        session = Openbis(bisurl, verify_certificates=False)
    return session

# %% [markdown]
# ## Connect to openBIS

# %%
session = log_in(bisurl='openbis', bisuser='admin', bispasswd='123456789')

# %% [markdown]
# ## Load all object schemas

# %%
objects_schemas_foldername = "New_Metadata_Schemas"
all_objects_schemas_filenames = [f"{objects_schemas_foldername}/{object_schema_filename}" for object_schema_filename in os.listdir(objects_schemas_foldername)]

# %% [markdown]
# ## Create property types, vocabularies, and object types

# %%
for object_schema_filename in all_objects_schemas_filenames:
    object_schema_file = load_json(object_schema_filename)
    
    # Create property types and vocabularies
    for property_code, property_settings in object_schema_file["properties"].items():
        
        # In openBIS, the property type "name" is already created and can be used to find objects in the GUI. Therefore, it should be used instead of creating a new one.
        if property_code == "name":
            property_code = "$name"
            
        if "openBISType" in property_settings:
            property_type_dict = {
                "code": property_code,
                "label": property_settings["title"],
                "description": property_settings["description"],
                "dataType": property_settings["openBISType"],
                "managedInternally": False,
            }
            
            if property_settings["openBISType"] == "CONTROLLEDVOCABULARY":
                
                vocabulary_dict = {
                    "code": f"{property_code}Vocabulary",
                    "description": f"{property_settings['title']} vocabulary",
                    "terms": []
                }
                
                if "enum" in property_settings:
                    for term in property_settings["enum"]:
                        term_dict = {
                            "code": term.replace(" ", ""),
                            "description": term,
                            "label": term
                        }
                        
                        vocabulary_dict["terms"].append(term_dict)
                else:
                    # Case when the terms are just the alphabetic letters
                    for term in list(string.ascii_lowercase):
                        term_dict = {
                            "code": term,
                            "description": term,
                            "label": term
                        }
                        
                        vocabulary_dict["terms"].append(term_dict)
                        
                try:
                    session.new_vocabulary(**vocabulary_dict).save()
                except ValueError:
                    print(f"{vocabulary_dict['code']} already exists.")
                
                property_type_dict["vocabulary"] = vocabulary_dict["code"]
            
            if "XML" in property_settings["openBISType"]:
                match = re.match(r"(\w+)\s\(([\w\s]+)\)", property_settings["openBISType"])
                property_type = match.group(1)
                custom_widget = match.group(2)
                property_type_dict["dataType"] = property_type
                property_type_dict["metaData"] = {"custom_widget": custom_widget}
            
            if property_settings["openBISType"] == "MULTILINE_VARCHAR":
                property_type_dict["metaData"] = {"custom_widget": "Word Processor"}
                
            try:
                session.new_property_type(**property_type_dict).save()
            except ValueError:
                print(f"{property_type_dict['code']} already exists.")

    # Create object types

    object_type_dict = {
        "code": object_schema_file["title"].replace(" ", "_"),
        "generatedCodePrefix": object_schema_file["openBISCode"]
    }

    try:
        object_type = session.get_object_type(object_type_dict["code"])
    except ValueError:
        print(f"{object_type_dict['code']} does not exist.")
        object_type = session.new_object_type(autoGeneratedCode=True, 
                                                subcodeUnique=False,
                                                listable=True,
                                                showContainer=False,
                                                showParents=True,
                                                showParentMetadata=False,
                                                **object_type_dict).save()

    for property_code in object_schema_file["properties"]:
        if property_code == "name":
            property_code = "$name"
        try:
            object_type.assign_property(session.get_property_type(code=property_code))
        except ValueError:
            print(f"{property_code} does not exist.")
    
    settings_sample = session.get_sample("/ELN_SETTINGS/GENERAL_ELN_SETTINGS")
    settings = json.loads(settings_sample.props["$eln_settings"])
    settings['sampleTypeDefinitionsExtension'][object_type.code] = {'SAMPLE_PARENTS_DISABLED': False,
                                                                    'SAMPLE_PARENTS_ANY_TYPE_DISABLED': False,
                                                                    'SAMPLE_CHILDREN_DISABLED': False,
                                                                    'SAMPLE_CHILDREN_ANY_TYPE_DISABLED': False,
                                                                    'USE_AS_PROTOCOL': False,
                                                                    'ENABLE_STORAGE': False,
                                                                    'SHOW': True, 
                                                                    'SHOW_ON_NAV': True}

    settings_sample.props['$eln_settings'] = json.dumps(settings)
    settings_sample.save()
# Out:
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the dosing.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "molecule_name", "label": "Molecule name", "description": "The name of the used gas molecule.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# molecule_name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "duration", "label": "Duration", "description": "Duration of the dosing.", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# duration already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "pressure", "label": "Pressure", "description": "Pressure of the dosing.", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# pressure already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "comments", "label": "Comments", "description": "Comments to the deposition.", "managedInternally": false, "dataType": "MULTILINE_VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": {"custom_widget": "Word Processor"}}]], "id": "2", "jsonrpc": "2.0"}
# comments already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DOSING", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to DOSING
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "MOLECULE_NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DOSING", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property MOLECULE_NAME already assigned to DOSING
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "DURATION"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DOSING", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property DURATION already assigned to DOSING
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "PRESSURE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DOSING", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property PRESSURE already assigned to DOSING
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "COMMENTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DOSING", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property COMMENTS already assigned to DOSING
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the person.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "short_name", "label": "Short name", "description": "The username of the person.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# short_name already exists.
# {"method": "createVocabularies", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.vocabulary.create.VocabularyCreation", "code": "work_statusVocabulary", "description": "Work status vocabulary", "managedInternally": false, "chosenFromList": true, "urlTemplate": null, "terms": [{"code": "active", "description": "active", "label": "active", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}, {"code": "inactive", "description": "inactive", "label": "inactive", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}]}]], "id": "2", "jsonrpc": "2.0"}
# work_statusVocabulary already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "work_status", "label": "Work status", "description": "Work status.", "managedInternally": false, "dataType": "CONTROLLEDVOCABULARY", "vocabularyId": {"@type": "as.dto.vocabulary.id.VocabularyPermId", "permId": "WORK_STATUSVOCABULARY"}, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# work_status already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "email", "label": "Email", "description": "The email of the person.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# email already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "work_phone", "label": "Work phone", "description": "The work phone of the person.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# work_phone already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "mobile_phone", "label": "Mobile phone", "description": "The mobile phone of the person.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# mobile_phone already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to PERSON
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "SHORT_NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property SHORT_NAME already assigned to PERSON
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WORK_STATUS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WORK_STATUS already assigned to PERSON
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "EMAIL"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property EMAIL already assigned to PERSON
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WORK_PHONE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WORK_PHONE already assigned to PERSON
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "MOBILE_PHONE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PERSON", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property MOBILE_PHONE already assigned to PERSON
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the PDOS object.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "wfms_uuid", "label": "WFMS UUID", "description": "Unique identifier of the simulation object in the WFMS.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# wfms_uuid already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "wfms_url", "label": "WFMS URL", "description": "Link to WFMS.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# wfms_url already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "atomic_selections", "label": "Atomic selections", "description": "List of group of atoms on which projections of the orbitals are computed", "managedInternally": false, "dataType": "ARRAY_STRING", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# atomic_selections already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "energies", "label": "Energies", "description": "Energy of each electronic state and its amplitude on the different projections.", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# energies already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "orbitals_selections", "label": "Orbitals selections", "description": "Amplitude of each gas phase orbital for a portion of the system on the orbitals of the full system", "managedInternally": false, "dataType": "ARRAY_REAL", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# orbitals_selections already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "comments", "label": "Comments", "description": "Comments to the PDOS.", "managedInternally": false, "dataType": "MULTILINE_VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": {"custom_widget": "Word Processor"}}]], "id": "2", "jsonrpc": "2.0"}
# comments already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WFMS_UUID"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WFMS_UUID already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WFMS_URL"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WFMS_URL already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ATOMIC_SELECTIONS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ATOMIC_SELECTIONS already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ENERGIES"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ENERGIES already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ORBITALS_SELECTIONS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ORBITALS_SELECTIONS already assigned to PDOS
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "COMMENTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "PDOS", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property COMMENTS already assigned to PDOS
# atomistic_model does not exist.
# density_functional_theory does not exist.
# tight_binding does not exist.
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the sample.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "SAMPLE", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to SAMPLE
# crystal does not exist.
# layered_2d_material does not exist.
# wafer_substrate does not exist.
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the maintenance.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "description", "label": "Description", "description": "Description of the maintenance.", "managedInternally": false, "dataType": "MULTILINE_VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": {"custom_widget": "Word Processor"}}]], "id": "2", "jsonrpc": "2.0"}
# description already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MAINTENANCE", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to MAINTENANCE
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "DESCRIPTION"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MAINTENANCE", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property DESCRIPTION already assigned to MAINTENANCE
# uhv_component does not exist.
# instrument does not exist.
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the draft.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createVocabularies", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.vocabulary.create.VocabularyCreation", "code": "draft_typeVocabulary", "description": "Draft type vocabulary", "managedInternally": false, "chosenFromList": true, "urlTemplate": null, "terms": [{"code": "preprint", "description": "preprint", "label": "preprint", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}, {"code": "postprint", "description": "postprint", "label": "postprint", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}]}]], "id": "2", "jsonrpc": "2.0"}
# draft_typeVocabulary already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "draft_type", "label": "Draft type", "description": "The type of the draft.", "managedInternally": false, "dataType": "CONTROLLEDVOCABULARY", "vocabularyId": {"@type": "as.dto.vocabulary.id.VocabularyPermId", "permId": "DRAFT_TYPEVOCABULARY"}, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# draft_type already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "comments", "label": "Comments", "description": "Comments to the draft.", "managedInternally": false, "dataType": "MULTILINE_VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": {"custom_widget": "Word Processor"}}]], "id": "2", "jsonrpc": "2.0"}
# comments already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DRAFT", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to DRAFT
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "DRAFT_TYPE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DRAFT", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property DRAFT_TYPE already assigned to DRAFT
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "COMMENTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "DRAFT", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property COMMENTS already assigned to DRAFT
# results does not exist.
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the STS.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "recording_time", "label": "Recording time", "description": "The date of the STS.", "managedInternally": false, "dataType": "TIMESTAMP", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# recording_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "duration", "label": "Duration", "description": "The duration of the STS.", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# duration already exists.
# {"method": "createVocabularies", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.vocabulary.create.VocabularyCreation", "code": "experiment_typeVocabulary", "description": "Experiment type vocabulary", "managedInternally": false, "chosenFromList": true, "urlTemplate": null, "terms": [{"code": "Biasspectroscopy", "description": "Bias spectroscopy", "label": "Bias spectroscopy", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}, {"code": "Z-spectroscopy", "description": "Z-spectroscopy", "label": "Z-spectroscopy", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}]}]], "id": "2", "jsonrpc": "2.0"}
# experiment_typeVocabulary already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "experiment_type", "label": "Experiment type", "description": "Experiment type", "managedInternally": false, "dataType": "CONTROLLEDVOCABULARY", "vocabularyId": {"@type": "as.dto.vocabulary.id.VocabularyPermId", "permId": "EXPERIMENT_TYPEVOCABULARY"}, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# experiment_type already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "acquisition_coordinates", "label": "Acquisition coordinates", "description": "Acquisition coordinates", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# acquisition_coordinates already exists.
# {"method": "createVocabularies", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.vocabulary.create.VocabularyCreation", "code": "feedback_activeVocabulary", "description": "Feedback active vocabulary", "managedInternally": false, "chosenFromList": true, "urlTemplate": null, "terms": [{"code": "active", "description": "active", "label": "active", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}, {"code": "inactive", "description": "inactive", "label": "inactive", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}]}]], "id": "2", "jsonrpc": "2.0"}
# feedback_activeVocabulary already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "feedback_active", "label": "Feedback active", "description": "Whether feedback is active", "managedInternally": false, "dataType": "CONTROLLEDVOCABULARY", "vocabularyId": {"@type": "as.dto.vocabulary.id.VocabularyPermId", "permId": "FEEDBACK_ACTIVEVOCABULARY"}, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# feedback_active already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "final_z", "label": "Final Z", "description": "Final Z", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# final_z already exists.
# {"method": "createVocabularies", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.vocabulary.create.VocabularyCreation", "code": "filter_typeVocabulary", "description": "Filter type vocabulary", "managedInternally": false, "chosenFromList": true, "urlTemplate": null, "terms": [{"code": "Butterworth", "description": "Butterworth", "label": "Butterworth", "@type": "as.dto.vocabulary.create.VocabularyTermCreation"}]}]], "id": "2", "jsonrpc": "2.0"}
# filter_typeVocabulary already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "filter_type", "label": "Filter type", "description": "Filter type", "managedInternally": false, "dataType": "CONTROLLEDVOCABULARY", "vocabularyId": {"@type": "as.dto.vocabulary.id.VocabularyPermId", "permId": "FILTER_TYPEVOCABULARY"}, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# filter_type already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "filter_order", "label": "Filter order", "description": "Filter order", "managedInternally": false, "dataType": "INTEGER", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# filter_order already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "filter_cutoff", "label": "Filter cutoff", "description": "Filter Cutoff", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# filter_cutoff already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "bias_settings", "label": "Bias settings", "description": "Bias voltage settings.", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# bias_settings already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "num_pixel", "label": "Number of pixels", "description": "Number of recorded points", "managedInternally": false, "dataType": "INTEGER", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# num_pixel already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "z_avg_time", "label": "Z average time", "description": "Duration over which the Z position is recorded and averaged before and after the sweep", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# z_avg_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "first_settling_time", "label": "First settling time", "description": "Additional time to wait (in addition to the Settling Time) after the bias has ramped to the starting point of the sweep", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# first_settling_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "settling_time", "label": "Settling time", "description": "Time to wait after changing the bias to the next level and before starting to acquire data", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# settling_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "integration_time", "label": "Integration time", "description": "Time during which the data are acquired and averaged", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# integration_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "end_settling_time", "label": "End settling time", "description": "Time to wait after the sweep has finished and the bias is ramped to the initial value", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# end_settling_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "z_control_time", "label": "Z-Controller time", "description": "Time during which the Z-controller is enabled once a sweep has finished", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# z_control_time already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "max_slew_rate", "label": "Max slew rate", "description": "Max rate at which the bias changes (before, during and after sweeping)", "managedInternally": false, "dataType": "JSON", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# max_slew_rate already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "backward_sweep", "label": "Backward sweep", "description": "Whether one wants to measure the backward (return) sweep or the forward only", "managedInternally": false, "dataType": "BOOLEAN", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# backward_sweep already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "num_sweeps", "label": "Number of sweeps", "description": "Number of sweeps to measure and average", "managedInternally": false, "dataType": "INTEGER", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# num_sweeps already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "channel_names", "label": "Channel names", "description": "Recorded channel names", "managedInternally": false, "dataType": "ARRAY_STRING", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# channel_names already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "record_final_z", "label": "Record final Z", "description": "Record the Z position during Z averaging time at the end of the sweep (after Z control time)", "managedInternally": false, "dataType": "BOOLEAN", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# record_final_z already exists.
# ...
# geometry_constraints already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "geometry_constraints_increments", "label": "Geometry constraints increments", "description": "Increments used to vary some of the constraints in case the constrained geometry optimisation method is used to determine the minimum energy path.", "managedInternally": false, "dataType": "ARRAY_REAL", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# geometry_constraints_increments already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "comments", "label": "Comments", "description": "Comments to the density functional theory.", "managedInternally": false, "dataType": "MULTILINE_VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": {"custom_widget": "Word Processor"}}]], "id": "2", "jsonrpc": "2.0"}
# comments already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WFMS_UUID"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WFMS_UUID already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WFMS_URL"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WFMS_URL already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "METHOD_TYPE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property METHOD_TYPE already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "NUMBER_GEOMETRIES"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property NUMBER_GEOMETRIES already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ENERGY_BARRIER"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ENERGY_BARRIER already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ENERGIES"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ENERGIES already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "GEOMETRY_CONSTRAINTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property GEOMETRY_CONSTRAINTS already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "GEOMETRY_CONSTRAINTS_INCREMENTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property GEOMETRY_CONSTRAINTS_INCREMENTS already assigned to MINIMUM_ENERGY_PATH
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "COMMENTS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "MINIMUM_ENERGY_PATH", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property COMMENTS already assigned to MINIMUM_ENERGY_PATH
# atomistic_models does not exist.
# sample successfully updated.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "$name", "label": "Name", "description": "The name of the supplier.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# $name already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "email", "label": "Email", "description": "The email of the supplier.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# email already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "work_phone", "label": "Work phone", "description": "The work phone of the supplier.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# work_phone already exists.
# {"method": "createPropertyTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"@type": "as.dto.property.create.PropertyTypeCreation", "code": "address", "label": "Address", "description": "The address of the supplier.", "managedInternally": false, "dataType": "VARCHAR", "vocabularyId": null, "materialTypeId": null, "schema": null, "transformation": null, "metaData": null}]], "id": "2", "jsonrpc": "2.0"}
# address already exists.
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "$NAME"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "SUPPLIER_CUSTOM", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property $NAME already assigned to SUPPLIER_CUSTOM
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "EMAIL"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "SUPPLIER_CUSTOM", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property EMAIL already assigned to SUPPLIER_CUSTOM
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "WORK_PHONE"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "SUPPLIER_CUSTOM", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property WORK_PHONE already assigned to SUPPLIER_CUSTOM
# {"method": "updateSampleTypes", "params": ["admin-240606103043861xFA8EB3804354A48BF6E747A9A0DB2FA4", [{"propertyAssignments": {"actions": [{"items": [{"section": null, "ordinal": null, "mandatory": false, "initialValueForExistingEntities": null, "showInEditView": true, "showRawValueInForms": true, "propertyTypeId": {"@type": "as.dto.property.id.PropertyTypePermId", "permId": "ADDRESS"}, "@type": "as.dto.property.create.PropertyAssignmentCreation", "unique": false}], "@type": "as.dto.common.update.ListUpdateActionAdd"}], "@type": "as.dto.entitytype.update.PropertyAssignmentListUpdateValue", "forceRemovingAssignments": false}, "@type": "as.dto.sample.update.SampleTypeUpdate", "typeId": {"@type": "as.dto.entitytype.id.EntityTypePermId", "permId": "SUPPLIER_CUSTOM", "entityKind": "SAMPLE"}}]], "id": "2", "jsonrpc": "2.0"}
# Property ADDRESS already assigned to SUPPLIER_CUSTOM
# sample successfully updated.

# %%
settings_sample = session.get_sample("/ELN_SETTINGS/GENERAL_ELN_SETTINGS")
settings = json.loads(settings_sample.props["$eln_settings"])
settings['sampleTypeDefinitionsExtension'][st.code] = {'SAMPLE_PARENTS_DISABLED': False,
                                                                 'SAMPLE_PARENTS_ANY_TYPE_DISABLED': False,
                                                                 'SAMPLE_CHILDREN_DISABLED': False,
                                                                 'SAMPLE_CHILDREN_ANY_TYPE_DISABLED': False,
                                                                 'USE_AS_PROTOCOL': False,
                                                                 'ENABLE_STORAGE': False,
                                                                 'SHOW': True, 
                                                                 'SHOW_ON_NAV': True}

settings_sample.props['$eln_settings'] = json.dumps(settings)
settings_sample.save()

# %%
settings_sample = session.get_sample("/ELN_SETTINGS/GENERAL_ELN_SETTINGS")
settings = json.loads(settings_sample.props["$eln_settings"])
# settings['sampleTypeDefinitionsExtension'] = {}

# settings['sampleTypeDefinitionsExtension'][object_type.code] = "{'SAMPLE_PARENTS_DISABLED': False, 'SAMPLE_PARENTS_ANY_TYPE_DISABLED': False, 'SAMPLE_CHILDREN_DISABLED': False, 'SAMPLE_CHILDREN_ANY_TYPE_DISABLED': False, 'USE_AS_PROTOCOL': False, 'ENABLE_STORAGE': False, 'SHOW': True, 'SHOW_ON_NAV': True}"

# settings_sample.props['$eln_settings'] = settings
# settings_sample.save()
